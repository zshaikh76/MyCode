# %%
print('test')
# Out:
# test

# %%
print('new line')
# Out:
# new line

# %%
a = 10

# %%
a
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
'this is strong'
# Out:
# 'this is strong'

# %%
'th'is is strong
# Out:
#   File "<ipython-input-7-e33e294c5368>", line 1
#     'th'is is strong
#             ^
# SyntaxError: invalid syntax

# %%
print('hello \tworld')
print('hello \nworld')
# Out:
# hello 	world
# hello
# world

# %%
len('hello world')
# Out:
# 11

# %%
mystring = "Hello World"

# %%
mystring
# Out:
# 'Hello World'

# %%
mystring[1]
# Out:
# 'e'

# %%
mystring[-1]
# Out:
# 'd'

# %%
mystring = 'abcdefghijk'

# %%
mystring
# Out:
# 'abcdefghijk'

# %%
mystring[2:]
# Out:
# 'cdefghijk'

# %%
mystring[3:6]
# Out:
# 'def'

# %%
mystring[1:4]
# Out:
# 'bcd'

# %%
mystring[2:7:2]
# Out:
# 'ceg'

# %%
mystring = "Hello world"
mystring[-3]
# Out:
# 'r'

# %%
mystring[:-1]
# Out:
# 'Hello worl'

# %%
x = "hello world"

# %%
x.upper()
# Out:
# 'HELLO WORLD'

# %%
x.split()
# Out:
# ['hello', 'world']

# %%
x.lower()
# Out:
# 'hello world'

# %%
print('The {q} {b} {f}'.format(f='fox' ,b='brown' ,q='quick'))
# Out:
# The quick brown fox

# %%
name='jose'

# %%
print('hello his name is {}'.format(name))
# Out:
# hello his name is jose

# %%
print(f'hello his name is {name}')
# Out:
# hello his name is jose

# %%
name='sam'
age=3

# %%
print(f'{name} is {age} years old')
# Out:
# sam is 3 years old
